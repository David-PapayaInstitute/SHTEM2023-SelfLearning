# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import PIL
import scipy
import tensorflow as tf
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
loc = 'drive/MyDrive/Shtem2023/'
# Out:
# Mounted at /content/drive/

# %%
os.listdir(loc + 'breastcancer')
# Out:
# ['class0', 'class1']

# %%
Xlist = []
for filename in os.listdir(loc+'breastcancer/class0'):
  img = PIL.Image.open(loc+'breastcancer/class0/'+filename)
  img2 = img.resize((300,300))
  arr = np.array(img2)
  Xlist.append(arr)
for filename in os.listdir(loc+'breastcancer/class1'):
  img = PIL.Image.open(loc+'breastcancer/class1/'+filename)
  img2 = img.resize((300,300))
  arr = np.array(img2)
  Xlist.append(arr)

# %%
X = np.array(Xlist)
X.shape
# Out:
# (979, 300, 300, 3)

# %%
xval = X[-120:]

# %%
Ylist = []
numCat = 2
for filename in os.listdir(loc+'breastcancer/class0'):
  if 'class1' in filename:
    label = [1,0] #1 on the left means cancer positive
  else:
    label = [0,1]
  Ylist.append(label)
for filename in os.listdir(loc+'breastcancer/class1'):
  if 'class1' in filename:
    label = [1,0] #1 on the left means cancer positive
  else:
    label = [0,1]
  Ylist.append(label)

# %%
Ylist
Y = np.array(Ylist)

print(Y.shape)
print(Y)
# Out:
# (979, 2)
# [[0 1]
#  [0 1]
#  [0 1]
#  ...
#  [1 0]
#  [1 0]
#  [1 0]]

# %%
PIL.Image.open(loc+'breastcancer/class1/'+'8863_idx5_x1801_y1201_class1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=50x50 at 0x7E75F46B03D0>

# %%
input_shape = X[0].shape
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=5,input_shape=input_shape, activation = 'relu'))
model.add(tf.keras.layers.Dense(units=5, activation = 'relu'))
model.add(tf.keras.layers.Conv2D(
    10,
    4,
    activation='relu'
))
model.add(tf.keras.layers.MaxPooling2D(
    pool_size=(2, 2),
    strides=2,
    padding='valid',
    data_format=None))
model.add(tf.keras.layers.Conv2D(
    10,
    4,
    activation='relu'
))
model.add(tf.keras.layers.MaxPooling2D(
    pool_size=(2, 2),
    strides=2,
    padding='valid',
    data_format=None))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dense(units=5, activation = 'relu'))
model.add(tf.keras.layers.Dense(units=numCat, activation = 'softmax'))

"""tf.keras.layers.MaxPooling2D(
    pool_size=(2, 2),
    strides=None,
    padding='valid',
    data_format=None
)"""
"""tf.keras.layers.Conv2D(
    filters,
    kernel_size,
    strides=(1, 1),
    padding='valid',
    data_format=None,
    dilation_rate=(1, 1),
    groups=1,
    activation=None
)"""
"""tf.keras.layers.BatchNormalization(
)"""
"""tf.keras.layers.Dropout(
    rate, noise_shape=None, seed=None, **kwargs
)"""
# after you create your model it's
# always a good habit to print out it's summary
model.summary()
# adam optimizer works pretty well for
# all kinds of problems and is a good starting point
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              # MAE error is good for
              # numerical predictions
              loss=tf.keras.losses.CategoricalCrossentropy(), metrics = tf.keras.metrics.CategoricalAccuracy(
    name='categorical_accuracy', dtype=None
))
losses = model.fit(X, Y,
                  # it will use 'batch_size' number
                  # of examples per example
                  batch_size=256,
                  epochs=3,  # total epoch
                  )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 300, 300, 5)       20
#
#  dense_1 (Dense)             (None, 300, 300, 5)       30
#
#  conv2d (Conv2D)             (None, 297, 297, 10)      810
#
#  max_pooling2d (MaxPooling2D  (None, 148, 148, 10)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 145, 145, 10)      1610
#
#  max_pooling2d_1 (MaxPooling  (None, 72, 72, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 51840)             0
#
#  batch_normalization (BatchN  (None, 51840)            207360
#  ormalization)
#
#  dense_2 (Dense)             (None, 5)                 259205
#
#  dense_3 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 469,047
# Trainable params: 365,367
# Non-trainable params: 103,680
# _________________________________________________________________
# Epoch 1/3
# 4/4 [==============================] - 126s 31s/step - loss: 21.0483 - categorical_accuracy: 0.5056
# Epoch 2/3
# 4/4 [==============================] - 113s 28s/step - loss: 2.3170 - categorical_accuracy: 0.7978
# Epoch 3/3
# 4/4 [==============================] - 111s 27s/step - loss: 1.1830 - categorical_accuracy: 0.7671

# %%
losses.history
# Out:
# {'loss': [21.04829978942871, 2.316962480545044, 1.183035135269165],
#  'categorical_accuracy': [0.5056179761886597,
#   0.7977527976036072,
#   0.7671092748641968]}

# %%
from sklearn.model_selection import train_test_split

# Split the data
x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.15, shuffle= True)

# %%
 for n in np.arange(100, 900, 50):
  x_train, x_valid, y_train, y_valid = train_test_split(X[:n], Y[:n], test_size=0.15, shuffle= True)
  input_shape = X[0].shape
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(units=5,input_shape=input_shape, activation = 'relu'))
  model.add(tf.keras.layers.Dense(units=5, activation = 'relu'))
  model.add(tf.keras.layers.Conv2D(
      10,
      4,
      activation='relu'
  ))
  model.add(tf.keras.layers.MaxPooling2D(
      pool_size=(2, 2),
      strides=2,
      padding='valid',
      data_format=None))
  model.add(tf.keras.layers.Conv2D(
      10,
      4,
      activation='relu'
  ))
  model.add(tf.keras.layers.MaxPooling2D(
      pool_size=(2, 2),
      strides=2,
      padding='valid',
      data_format=None))
  model.add(tf.keras.layers.Conv2D(
      10,
      4,
      activation='relu'
  ))
  model.add(tf.keras.layers.MaxPooling2D(
      pool_size=(2, 2),
      strides=2,
      padding='valid',
      data_format=None))
  model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dense(units=5, activation = 'relu'))
  model.add(tf.keras.layers.Dense(units=numCat, activation = 'softmax'))

  """tf.keras.layers.MaxPooling2D(
      pool_size=(2, 2),
      strides=None,
      padding='valid',
      data_format=None
  )"""
  """tf.keras.layers.Conv2D(
      filters,
      kernel_size,
      strides=(1, 1),
      padding='valid',
      data_format=None,
      dilation_rate=(1, 1),
      groups=1,
      activation=None
  )"""
  """tf.keras.layers.BatchNormalization(
  )"""
  """tf.keras.layers.Dropout(
      rate, noise_shape=None, seed=None, **kwargs
  )"""
  # after you create your model it's
  # always a good habit to print out it's summary
  model.summary()
  # adam optimizer works pretty well for
  # all kinds of problems and is a good starting point
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                # MAE error is good for
                # numerical predictions
                loss=tf.keras.losses.CategoricalCrossentropy(), metrics = tf.keras.metrics.CategoricalAccuracy(
      name='categorical_accuracy', dtype=None
  ))
  losses = model.fit(x_train, y_train,
                    # it will use 'batch_size' number
                    # of examples per example
                    batch_size=256,
                    epochs=3,  # total epoch
                    validation_data = (x_valid, y_valid)
                    )
  df = pd.DataFrame(losses.history)
  df.to_csv(loc + 'Saniya' + str(n) + '.csv')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 300, 300, 5)       20
#
#  dense_5 (Dense)             (None, 300, 300, 5)       30
#
#  conv2d_2 (Conv2D)           (None, 297, 297, 10)      810
#
#  max_pooling2d_2 (MaxPooling  (None, 148, 148, 10)     0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 145, 145, 10)      1610
#
#  max_pooling2d_3 (MaxPooling  (None, 72, 72, 10)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 69, 69, 10)        1610
#
#  max_pooling2d_4 (MaxPooling  (None, 34, 34, 10)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 11560)             0
#
#  batch_normalization_1 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_6 (Dense)             (None, 5)                 57805
#
#  dense_7 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 1/1 [==============================] - 13s 13s/step - loss: 0.5067 - categorical_accuracy: 0.8118 - val_loss: 124.5350 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 9s 9s/step - loss: 1.0642 - categorical_accuracy: 0.5765 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 1/1 [==============================] - 11s 11s/step - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 300, 300, 5)       20
#
#  dense_9 (Dense)             (None, 300, 300, 5)       30
#
#  conv2d_5 (Conv2D)           (None, 297, 297, 10)      810
#
#  max_pooling2d_5 (MaxPooling  (None, 148, 148, 10)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 145, 145, 10)      1610
#
#  max_pooling2d_6 (MaxPooling  (None, 72, 72, 10)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 69, 69, 10)        1610
#
#  max_pooling2d_7 (MaxPooling  (None, 34, 34, 10)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 11560)             0
#
#  batch_normalization_2 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_10 (Dense)            (None, 5)                 57805
#
#  dense_11 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 1/1 [==============================] - 18s 18s/step - loss: 0.7762 - categorical_accuracy: 0.5276 - val_loss: 166.5781 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 16s 16s/step - loss: 2.2766 - categorical_accuracy: 0.5906 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 1/1 [==============================] - 16s 16s/step - loss: 0.7356 - categorical_accuracy: 0.5512 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 300, 300, 5)       20
#
#  dense_13 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_8 (Conv2D)           (None, 297, 297, 10)      810
#
#  max_pooling2d_8 (MaxPooling  (None, 148, 148, 10)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 145, 145, 10)      1610
#
#  max_pooling2d_9 (MaxPooling  (None, 72, 72, 10)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_10 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 11560)             0
#
#  batch_normalization_3 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_14 (Dense)            (None, 5)                 57805
#
#  dense_15 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 1/1 [==============================] - 25s 25s/step - loss: 0.8711 - categorical_accuracy: 0.6353 - val_loss: 606.9645 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 20s 20s/step - loss: 2.7665 - categorical_accuracy: 0.5176 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 1/1 [==============================] - 22s 22s/step - loss: 0.0340 - categorical_accuracy: 0.9882 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 300, 300, 5)       20
#
#  dense_17 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_11 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_11 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_12 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_13 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 11560)             0
#
#  batch_normalization_4 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_18 (Dense)            (None, 5)                 57805
#
#  dense_19 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# WARNING:tensorflow:5 out of the last 22 calls to <function Model.make_train_function.<locals>.train_function at 0x7e75bdbe7b50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 30s 30s/step - loss: 0.5087 - categorical_accuracy: 0.6745 - val_loss: 8.3158 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 35s 35s/step - loss: 0.3670 - categorical_accuracy: 0.7783 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 1/1 [==============================] - 33s 33s/step - loss: 0.0310 - categorical_accuracy: 0.9906 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 300, 300, 5)       20
#
#  dense_21 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_14 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_14 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_15 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_16 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 11560)             0
#
#  batch_normalization_5 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_22 (Dense)            (None, 5)                 57805
#
#  dense_23 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_train_function.<locals>.train_function at 0x7e75d36e6e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s - loss: 0.6449 - categorical_accuracy: 0.6275
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7e75d36e70a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 37s 37s/step - loss: 0.6449 - categorical_accuracy: 0.6275 - val_loss: 206.3121 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 31s 31s/step - loss: 0.6948 - categorical_accuracy: 0.6706 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 1/1 [==============================] - 32s 32s/step - loss: 3.7664 - categorical_accuracy: 0.7098 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 300, 300, 5)       20
#
#  dense_25 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_17 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_17 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_18 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_19 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 11560)             0
#
#  batch_normalization_6 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_26 (Dense)            (None, 5)                 57805
#
#  dense_27 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 2/2 [==============================] - ETA: 0s - loss: 0.5628 - categorical_accuracy: 0.6667
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7e75d3c83eb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 41s 8s/step - loss: 0.5628 - categorical_accuracy: 0.6667 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 2/3
# 2/2 [==============================] - 42s 9s/step - loss: 0.4983 - categorical_accuracy: 0.9360 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 2/2 [==============================] - 37s 7s/step - loss: 0.0037 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 300, 300, 5)       20
#
#  dense_29 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_20 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_20 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_21 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_22 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 11560)             0
#
#  batch_normalization_7 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_30 (Dense)            (None, 5)                 57805
#
#  dense_31 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 2/2 [==============================] - 45s 12s/step - loss: 0.9211 - categorical_accuracy: 0.5059 - val_loss: 339.5327 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 2/2 [==============================] - 43s 13s/step - loss: 0.4859 - categorical_accuracy: 0.7441 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 2/2 [==============================] - 44s 13s/step - loss: 0.0173 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 300, 300, 5)       20
#
#  dense_33 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_23 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_23 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_24 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_25 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 11560)             0
#
#  batch_normalization_8 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_34 (Dense)            (None, 5)                 57805
#
#  dense_35 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 2/2 [==============================] - 52s 21s/step - loss: 0.4370 - categorical_accuracy: 0.8141 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 2/3
# 2/2 [==============================] - 47s 17s/step - loss: 0.0389 - categorical_accuracy: 0.9843 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 2/2 [==============================] - 48s 17s/step - loss: 0.0250 - categorical_accuracy: 0.9895 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 300, 300, 5)       20
#
#  dense_37 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_26 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_26 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_27 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_28 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 11560)             0
#
#  batch_normalization_9 (Batc  (None, 11560)            46240
#  hNormalization)
#
#  dense_38 (Dense)            (None, 5)                 57805
#
#  dense_39 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 2/2 [==============================] - 60s 22s/step - loss: 9.2864 - categorical_accuracy: 0.0306 - val_loss: 3985.3142 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 2/2 [==============================] - 57s 23s/step - loss: 12.8957 - categorical_accuracy: 0.4565 - val_loss: 615.9225 - val_categorical_accuracy: 0.0000e+00
# Epoch 3/3
# 2/2 [==============================] - 55s 24s/step - loss: 1.3485 - categorical_accuracy: 0.6400 - val_loss: 95.8921 - val_categorical_accuracy: 0.0000e+00
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 300, 300, 5)       20
#
#  dense_41 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_29 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_29 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_30 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_31 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 11560)             0
#
#  batch_normalization_10 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_42 (Dense)            (None, 5)                 57805
#
#  dense_43 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 2/2 [==============================] - 61s 29s/step - loss: 7.0141 - categorical_accuracy: 0.4797 - val_loss: 1982.2643 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 2/2 [==============================] - 59s 28s/step - loss: 8.1856 - categorical_accuracy: 0.5161 - val_loss: 0.6540 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 2/2 [==============================] - 62s 29s/step - loss: 0.4350 - categorical_accuracy: 0.9872 - val_loss: 0.6363 - val_categorical_accuracy: 1.0000
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_44 (Dense)            (None, 300, 300, 5)       20
#
#  dense_45 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_32 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_32 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_33 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_34 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 11560)             0
#
#  batch_normalization_11 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_46 (Dense)            (None, 5)                 57805
#
#  dense_47 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 2/2 [==============================] - 66s 33s/step - loss: 4.4254 - categorical_accuracy: 0.0020 - val_loss: 1253.9967 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 2/2 [==============================] - 65s 34s/step - loss: 11.6587 - categorical_accuracy: 0.0627 - val_loss: 1664.1111 - val_categorical_accuracy: 0.0000e+00
# Epoch 3/3
# 2/2 [==============================] - 74s 41s/step - loss: 5.5938 - categorical_accuracy: 0.2490 - val_loss: 418.4669 - val_categorical_accuracy: 0.0000e+00
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 300, 300, 5)       20
#
#  dense_49 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_35 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_35 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_36 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_37 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 11560)             0
#
#  batch_normalization_12 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_50 (Dense)            (None, 5)                 57805
#
#  dense_51 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 3/3 [==============================] - 75s 21s/step - loss: 9.8653 - categorical_accuracy: 0.0308 - val_loss: 692.8589 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/3
# 3/3 [==============================] - 70s 20s/step - loss: 6.2840 - categorical_accuracy: 0.3170 - val_loss: 0.6360 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 3/3 [==============================] - 69s 20s/step - loss: 0.3652 - categorical_accuracy: 0.9855 - val_loss: 0.6128 - val_categorical_accuracy: 1.0000
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_52 (Dense)            (None, 300, 300, 5)       20
#
#  dense_53 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_38 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_38 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_39 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_40 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_13 (Flatten)        (None, 11560)             0
#
#  batch_normalization_13 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_54 (Dense)            (None, 5)                 57805
#
#  dense_55 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 3/3 [==============================] - 76s 22s/step - loss: 0.2591 - categorical_accuracy: 0.9160 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 2/3
# 3/3 [==============================] - 77s 23s/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 3/3 [==============================] - 77s 22s/step - loss: 7.7464e-05 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_56 (Dense)            (None, 300, 300, 5)       20
#
#  dense_57 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_41 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_41 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_42 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_43 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_14 (Flatten)        (None, 11560)             0
#
#  batch_normalization_14 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_58 (Dense)            (None, 5)                 57805
#
#  dense_59 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 3/3 [==============================] - 91s 29s/step - loss: 3.4286 - categorical_accuracy: 0.4961 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 2/3
# 3/3 [==============================] - 83s 26s/step - loss: 0.2626 - categorical_accuracy: 0.9796 - val_loss: 0.6391 - val_categorical_accuracy: 1.0000
# Epoch 3/3
# 3/3 [==============================] - 81s 25s/step - loss: 5.7969e-04 - categorical_accuracy: 1.0000 - val_loss: 0.1141 - val_categorical_accuracy: 1.0000
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_60 (Dense)            (None, 300, 300, 5)       20
#
#  dense_61 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_44 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_44 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_45 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_45 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_46 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 11560)             0
#
#  batch_normalization_15 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_62 (Dense)            (None, 5)                 57805
#
#  dense_63 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 3/3 [==============================] - 88s 28s/step - loss: 21.4326 - categorical_accuracy: 0.0853 - val_loss: 160.5928 - val_categorical_accuracy: 0.0333
# Epoch 2/3
# 3/3 [==============================] - 90s 28s/step - loss: 1.6928 - categorical_accuracy: 0.8176 - val_loss: 61.8397 - val_categorical_accuracy: 0.0333
# Epoch 3/3
# 3/3 [==============================] - 92s 31s/step - loss: 0.2219 - categorical_accuracy: 0.9647 - val_loss: 218.4819 - val_categorical_accuracy: 0.0333
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_64 (Dense)            (None, 300, 300, 5)       20
#
#  dense_65 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_47 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_47 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_48 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_48 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_49 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_16 (Flatten)        (None, 11560)             0
#
#  batch_normalization_16 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_66 (Dense)            (None, 5)                 57805
#
#  dense_67 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/3
# 3/3 [==============================] - 94s 31s/step - loss: 0.5596 - categorical_accuracy: 0.8296 - val_loss: 51.4290 - val_categorical_accuracy: 0.8984
# Epoch 2/3
# 3/3 [==============================] - 98s 31s/step - loss: 0.3337 - categorical_accuracy: 0.8975 - val_loss: 161.2153 - val_categorical_accuracy: 0.8984
# Epoch 3/3
# 3/3 [==============================] - 89s 29s/step - loss: 0.2935 - categorical_accuracy: 0.9072 - val_loss: 149.4380 - val_categorical_accuracy: 0.8984

# %%
##model below is with a test_size of 0.25 and 15 epochs (Saniya_V2_)

# %%
 for n in np.arange(100, 900, 50):
  x_train, x_valid, y_train, y_valid = train_test_split(X[:n], Y[:n], test_size=0.25, shuffle= True)
  input_shape = X[0].shape
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(units=5,input_shape=input_shape, activation = 'relu'))
  model.add(tf.keras.layers.Dense(units=5, activation = 'relu'))
  model.add(tf.keras.layers.Conv2D(
      10,
      4,
      activation='relu'
  ))
  model.add(tf.keras.layers.MaxPooling2D(
      pool_size=(2, 2),
      strides=2,
      padding='valid',
      data_format=None))
  model.add(tf.keras.layers.Conv2D(
      10,
      4,
      activation='relu'
  ))
  model.add(tf.keras.layers.MaxPooling2D(
      pool_size=(2, 2),
      strides=2,
      padding='valid',
      data_format=None))
  model.add(tf.keras.layers.Conv2D(
      10,
      4,
      activation='relu'
  ))
  model.add(tf.keras.layers.MaxPooling2D(
      pool_size=(2, 2),
      strides=2,
      padding='valid',
      data_format=None))
  model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dense(units=5, activation = 'relu'))
  model.add(tf.keras.layers.Dense(units=numCat, activation = 'softmax'))

  """tf.keras.layers.MaxPooling2D(
      pool_size=(2, 2),
      strides=None,
      padding='valid',
      data_format=None
  )"""
  """tf.keras.layers.Conv2D(
      filters,
      kernel_size,
      strides=(1, 1),
      padding='valid',
      data_format=None,
      dilation_rate=(1, 1),
      groups=1,
      activation=None
  )"""
  """tf.keras.layers.BatchNormalization(
  )"""
  """tf.keras.layers.Dropout(
      rate, noise_shape=None, seed=None, **kwargs
  )"""
  # after you create your model it's
  # always a good habit to print out it's summary
  model.summary()
  # adam optimizer works pretty well for
  # all kinds of problems and is a good starting point
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                # MAE error is good for
                # numerical predictions
                loss=tf.keras.losses.CategoricalCrossentropy(), metrics = tf.keras.metrics.CategoricalAccuracy(
      name='categorical_accuracy', dtype=None
  ))
  losses = model.fit(x_train, y_train,
                    # it will use 'batch_size' number
                    # of examples per example
                    batch_size=256,
                    epochs=15,  # total epoch
                    validation_data = (x_valid, y_valid)
                    )
  df = pd.DataFrame(losses.history)
  df.to_csv(loc + 'Saniya_V2_' + str(n) + '.csv')
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_68 (Dense)            (None, 300, 300, 5)       20
#
#  dense_69 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_50 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_50 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_51 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_51 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_52 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_52 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_17 (Flatten)        (None, 11560)             0
#
#  batch_normalization_17 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_70 (Dense)            (None, 5)                 57805
#
#  dense_71 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.5321 - categorical_accuracy: 0.6533 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 2/15
# 1/1 [==============================] - 12s 12s/step - loss: 0.0610 - categorical_accuracy: 0.9733 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 1/1 [==============================] - 9s 9s/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 4/15
# 1/1 [==============================] - 13s 13s/step - loss: 2.3851e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 1/1 [==============================] - 12s 12s/step - loss: 8.0501e-05 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 1/1 [==============================] - 10s 10s/step - loss: 2.0285e-05 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 1/1 [==============================] - 10s 10s/step - loss: 4.9645e-06 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 1/1 [==============================] - 12s 12s/step - loss: 1.2302e-06 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 1/1 [==============================] - 9s 9s/step - loss: 3.2107e-07 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 1/1 [==============================] - 11s 11s/step - loss: 9.0599e-08 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 1/1 [==============================] - 12s 12s/step - loss: 2.7021e-08 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 1/1 [==============================] - 9s 9s/step - loss: 9.5367e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 1/1 [==============================] - 11s 11s/step - loss: 3.1789e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 1/1 [==============================] - 12s 12s/step - loss: 1.5895e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 1/1 [==============================] - 10s 10s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_72 (Dense)            (None, 300, 300, 5)       20
#
#  dense_73 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_53 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_53 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_54 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_55 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_55 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_18 (Flatten)        (None, 11560)             0
#
#  batch_normalization_18 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_74 (Dense)            (None, 5)                 57805
#
#  dense_75 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 1/1 [==============================] - 18s 18s/step - loss: 0.6687 - categorical_accuracy: 0.5625 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 2/15
# 1/1 [==============================] - 24s 24s/step - loss: 0.3984 - categorical_accuracy: 0.9107 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.3129 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 4/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.3087 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 1/1 [==============================] - 14s 14s/step - loss: 0.3006 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.2895 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 1/1 [==============================] - 14s 14s/step - loss: 0.2821 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.2756 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.2718 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 1/1 [==============================] - 17s 17s/step - loss: 0.2682 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 1/1 [==============================] - 19s 19s/step - loss: 0.2646 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.2610 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.2575 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 1/1 [==============================] - 16s 16s/step - loss: 0.2540 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 1/1 [==============================] - 15s 15s/step - loss: 0.2505 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_76 (Dense)            (None, 300, 300, 5)       20
#
#  dense_77 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_56 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_56 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_57 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_57 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_58 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_58 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_19 (Flatten)        (None, 11560)             0
#
#  batch_normalization_19 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_78 (Dense)            (None, 5)                 57805
#
#  dense_79 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 1/1 [==============================] - 24s 24s/step - loss: 0.8050 - categorical_accuracy: 0.6200 - val_loss: 4627.0063 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/15
# 1/1 [==============================] - 25s 25s/step - loss: 12.4405 - categorical_accuracy: 0.4533 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 1/1 [==============================] - 21s 21s/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 4/15
# 1/1 [==============================] - 26s 26s/step - loss: 6.0465 - categorical_accuracy: 0.7133 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 1/1 [==============================] - 20s 20s/step - loss: 1.0322e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 1/1 [==============================] - 24s 24s/step - loss: 2.3770e-05 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 1/1 [==============================] - 22s 22s/step - loss: 9.3532e-06 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 1/1 [==============================] - 21s 21s/step - loss: 8.6859e-07 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 1/1 [==============================] - 21s 21s/step - loss: 1.0570e-07 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 1/1 [==============================] - 22s 22s/step - loss: 1.8279e-08 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 1/1 [==============================] - 21s 21s/step - loss: 5.5631e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 1/1 [==============================] - 22s 22s/step - loss: 2.3842e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 1/1 [==============================] - 22s 22s/step - loss: 1.5895e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 1/1 [==============================] - 21s 21s/step - loss: 7.9473e-10 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 1/1 [==============================] - 26s 26s/step - loss: 7.9473e-10 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_80 (Dense)            (None, 300, 300, 5)       20
#
#  dense_81 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_59 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_59 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_60 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_60 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_61 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_61 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_20 (Flatten)        (None, 11560)             0
#
#  batch_normalization_20 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_82 (Dense)            (None, 5)                 57805
#
#  dense_83 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 1/1 [==============================] - 30s 30s/step - loss: 0.8142 - categorical_accuracy: 0.4332 - val_loss: 57.5837 - val_categorical_accuracy: 0.0159
# Epoch 2/15
# 1/1 [==============================] - 27s 27s/step - loss: 0.5376 - categorical_accuracy: 0.7647 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 1/1 [==============================] - 25s 25s/step - loss: 5.3724 - categorical_accuracy: 0.6257 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 4/15
# 1/1 [==============================] - 28s 28s/step - loss: 0.0078 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 1/1 [==============================] - 28s 28s/step - loss: 1.3416e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 1/1 [==============================] - 25s 25s/step - loss: 1.7683e-06 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 1/1 [==============================] - 27s 27s/step - loss: 7.0760e-08 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 1/1 [==============================] - 30s 30s/step - loss: 6.3748e-10 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 1/1 [==============================] - 26s 26s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 1/1 [==============================] - 26s 26s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 1/1 [==============================] - 29s 29s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 1/1 [==============================] - 25s 25s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 1/1 [==============================] - 27s 27s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 1/1 [==============================] - 29s 29s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 1/1 [==============================] - 28s 28s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_84 (Dense)            (None, 300, 300, 5)       20
#
#  dense_85 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_62 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_62 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_63 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_63 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_64 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_64 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_21 (Flatten)        (None, 11560)             0
#
#  batch_normalization_21 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_86 (Dense)            (None, 5)                 57805
#
#  dense_87 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 1/1 [==============================] - 35s 35s/step - loss: 0.6788 - categorical_accuracy: 0.6444 - val_loss: 0.0666 - val_categorical_accuracy: 1.0000
# Epoch 2/15
# 1/1 [==============================] - 32s 32s/step - loss: 0.6455 - categorical_accuracy: 0.7911 - val_loss: 125.6651 - val_categorical_accuracy: 0.0000e+00
# Epoch 3/15
# 1/1 [==============================] - 32s 32s/step - loss: 0.6744 - categorical_accuracy: 0.7956 - val_loss: 111.9043 - val_categorical_accuracy: 0.0133
# Epoch 4/15
# 1/1 [==============================] - 31s 31s/step - loss: 0.0152 - categorical_accuracy: 0.9956 - val_loss: 204.4223 - val_categorical_accuracy: 0.0000e+00
# Epoch 5/15
# 1/1 [==============================] - 30s 30s/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 297.0352 - val_categorical_accuracy: 0.0000e+00
# Epoch 6/15
# 1/1 [==============================] - 33s 33s/step - loss: 0.0089 - categorical_accuracy: 0.9956 - val_loss: 343.4577 - val_categorical_accuracy: 0.0000e+00
# Epoch 7/15
# 1/1 [==============================] - 34s 34s/step - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 405.8016 - val_categorical_accuracy: 0.0000e+00
# Epoch 8/15
# 1/1 [==============================] - 34s 34s/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 295.9033 - val_categorical_accuracy: 0.0000e+00
# Epoch 9/15
# 1/1 [==============================] - 31s 31s/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 201.8566 - val_categorical_accuracy: 0.0000e+00
# Epoch 10/15
# 1/1 [==============================] - 32s 32s/step - loss: 7.2195e-06 - categorical_accuracy: 1.0000 - val_loss: 118.3028 - val_categorical_accuracy: 0.0800
# Epoch 11/15
# 1/1 [==============================] - 33s 33s/step - loss: 3.6325e-06 - categorical_accuracy: 1.0000 - val_loss: 79.9681 - val_categorical_accuracy: 0.3733
# Epoch 12/15
# 1/1 [==============================] - 32s 32s/step - loss: 3.8828e-06 - categorical_accuracy: 1.0000 - val_loss: 59.1158 - val_categorical_accuracy: 0.5067
# Epoch 13/15
# 1/1 [==============================] - 33s 33s/step - loss: 2.5935e-06 - categorical_accuracy: 1.0000 - val_loss: 46.3405 - val_categorical_accuracy: 0.6000
# Epoch 14/15
# 1/1 [==============================] - 37s 37s/step - loss: 2.2243e-06 - categorical_accuracy: 1.0000 - val_loss: 37.8785 - val_categorical_accuracy: 0.6267
# Epoch 15/15
# 1/1 [==============================] - 31s 31s/step - loss: 2.4254e-06 - categorical_accuracy: 1.0000 - val_loss: 31.3092 - val_categorical_accuracy: 0.6533
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_88 (Dense)            (None, 300, 300, 5)       20
#
#  dense_89 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_65 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_65 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_66 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_66 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_67 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_67 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_22 (Flatten)        (None, 11560)             0
#
#  batch_normalization_22 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_90 (Dense)            (None, 5)                 57805
#
#  dense_91 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 2/2 [==============================] - 40s 6s/step - loss: 0.7745 - categorical_accuracy: 0.5191 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 2/15
# 2/2 [==============================] - 34s 3s/step - loss: 0.3738 - categorical_accuracy: 0.9427 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 2/2 [==============================] - 34s 3s/step - loss: 0.0061 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 4/15
# 2/2 [==============================] - 33s 3s/step - loss: 0.0292 - categorical_accuracy: 0.9962 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 2/2 [==============================] - 38s 6s/step - loss: 0.0390 - categorical_accuracy: 0.9924 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 2/2 [==============================] - 33s 3s/step - loss: 1.2541e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 2/2 [==============================] - 33s 3s/step - loss: 0.0036 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 2/2 [==============================] - 33s 3s/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 2/2 [==============================] - 36s 6s/step - loss: 0.0030 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 2/2 [==============================] - 33s 3s/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 2/2 [==============================] - 33s 3s/step - loss: 0.0070 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 2/2 [==============================] - 36s 3s/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 2/2 [==============================] - 36s 6s/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 2/2 [==============================] - 33s 3s/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 2/2 [==============================] - 34s 3s/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_92 (Dense)            (None, 300, 300, 5)       20
#
#  dense_93 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_68 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_68 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_69 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_69 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_70 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_70 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_23 (Flatten)        (None, 11560)             0
#
#  batch_normalization_23 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_94 (Dense)            (None, 5)                 57805
#
#  dense_95 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 2/2 [==============================] - 41s 9s/step - loss: 3.3696 - categorical_accuracy: 0.1567 - val_loss: 2247.5896 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/15
# 2/2 [==============================] - 40s 10s/step - loss: 9.4754 - categorical_accuracy: 0.4567 - val_loss: 0.6545 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 2/2 [==============================] - 42s 10s/step - loss: 0.3476 - categorical_accuracy: 1.0000 - val_loss: 130.1633 - val_categorical_accuracy: 0.0000e+00
# Epoch 4/15
# 2/2 [==============================] - 40s 10s/step - loss: 0.2948 - categorical_accuracy: 0.9933 - val_loss: 0.6228 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 2/2 [==============================] - 40s 10s/step - loss: 0.2714 - categorical_accuracy: 1.0000 - val_loss: 0.6089 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 2/2 [==============================] - 40s 10s/step - loss: 0.4264 - categorical_accuracy: 0.9767 - val_loss: 0.5954 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 2/2 [==============================] - 42s 12s/step - loss: 0.2616 - categorical_accuracy: 0.9967 - val_loss: 0.5825 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 2/2 [==============================] - 41s 11s/step - loss: 0.2465 - categorical_accuracy: 1.0000 - val_loss: 0.5701 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 2/2 [==============================] - 42s 10s/step - loss: 0.2321 - categorical_accuracy: 1.0000 - val_loss: 0.5584 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 2/2 [==============================] - 40s 10s/step - loss: 0.2254 - categorical_accuracy: 0.9967 - val_loss: 0.5470 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 2/2 [==============================] - 40s 10s/step - loss: 0.2168 - categorical_accuracy: 1.0000 - val_loss: 0.5360 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 2/2 [==============================] - 40s 10s/step - loss: 0.2143 - categorical_accuracy: 1.0000 - val_loss: 0.5252 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 2/2 [==============================] - 40s 10s/step - loss: 0.2050 - categorical_accuracy: 1.0000 - val_loss: 0.5147 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 2/2 [==============================] - 44s 11s/step - loss: 0.1975 - categorical_accuracy: 1.0000 - val_loss: 0.5044 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 2/2 [==============================] - 42s 12s/step - loss: 0.1936 - categorical_accuracy: 1.0000 - val_loss: 0.4944 - val_categorical_accuracy: 1.0000
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_96 (Dense)            (None, 300, 300, 5)       20
#
#  dense_97 (Dense)            (None, 300, 300, 5)       30
#
#  conv2d_71 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_71 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_72 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_72 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_73 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_73 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_24 (Flatten)        (None, 11560)             0
#
#  batch_normalization_24 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_98 (Dense)            (None, 5)                 57805
#
#  dense_99 (Dense)            (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 2/2 [==============================] - 48s 16s/step - loss: 0.4394 - categorical_accuracy: 0.8071 - val_loss: 2077.9446 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/15
# 2/2 [==============================] - 44s 14s/step - loss: 4.6594e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 2/2 [==============================] - 46s 16s/step - loss: 7.3006e-06 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 4/15
# 2/2 [==============================] - 48s 16s/step - loss: 2.0340e-07 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 2/2 [==============================] - 44s 13s/step - loss: 8.1359e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 2/2 [==============================] - 46s 16s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 2/2 [==============================] - 45s 16s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 2/2 [==============================] - 45s 16s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 2/2 [==============================] - 48s 16s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 2/2 [==============================] - 45s 15s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 2/2 [==============================] - 44s 14s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 2/2 [==============================] - 51s 16s/step - loss: 4.1387e-08 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 2/2 [==============================] - 49s 18s/step - loss: 2.8299e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 2/2 [==============================] - 46s 16s/step - loss: 3.5374e-10 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 2/2 [==============================] - 46s 16s/step - loss: 2.2355e-07 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_100 (Dense)           (None, 300, 300, 5)       20
#
#  dense_101 (Dense)           (None, 300, 300, 5)       30
#
#  conv2d_74 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_74 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_75 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_75 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_76 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_76 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_25 (Flatten)        (None, 11560)             0
#
#  batch_normalization_25 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_102 (Dense)           (None, 5)                 57805
#
#  dense_103 (Dense)           (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 2/2 [==============================] - 53s 20s/step - loss: 6.5542 - categorical_accuracy: 0.0987 - val_loss: 837.4540 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/15
# 2/2 [==============================] - 54s 20s/step - loss: 13.1590 - categorical_accuracy: 0.1787 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 2/2 [==============================] - 50s 19s/step - loss: 0.3750 - categorical_accuracy: 0.9840 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 4/15
# 2/2 [==============================] - 53s 24s/step - loss: 0.3447 - categorical_accuracy: 0.9973 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 2/2 [==============================] - 50s 19s/step - loss: 0.3313 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 2/2 [==============================] - 57s 24s/step - loss: 0.3271 - categorical_accuracy: 0.9973 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 2/2 [==============================] - 54s 19s/step - loss: 0.3105 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 2/2 [==============================] - 55s 24s/step - loss: 0.3074 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 2/2 [==============================] - 48s 17s/step - loss: 0.3006 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 2/2 [==============================] - 49s 19s/step - loss: 0.2892 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 2/2 [==============================] - 47s 18s/step - loss: 0.2838 - categorical_accuracy: 0.9973 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 2/2 [==============================] - 50s 20s/step - loss: 0.2772 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 2/2 [==============================] - 49s 19s/step - loss: 0.2723 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 2/2 [==============================] - 54s 24s/step - loss: 0.2641 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 2/2 [==============================] - 48s 18s/step - loss: 0.2598 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_104 (Dense)           (None, 300, 300, 5)       20
#
#  dense_105 (Dense)           (None, 300, 300, 5)       30
#
#  conv2d_77 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_77 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_78 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_78 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_79 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_79 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_26 (Flatten)        (None, 11560)             0
#
#  batch_normalization_26 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_106 (Dense)           (None, 5)                 57805
#
#  dense_107 (Dense)           (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 2/2 [==============================] - 60s 25s/step - loss: 10.9852 - categorical_accuracy: 0.4733 - val_loss: 86.0711 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/15
# 2/2 [==============================] - 53s 23s/step - loss: 0.4526 - categorical_accuracy: 0.8835 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 3/15
# 2/2 [==============================] - 53s 23s/step - loss: 0.0292 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 4/15
# 2/2 [==============================] - 53s 23s/step - loss: 2.8770e-05 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 5/15
# 2/2 [==============================] - 57s 23s/step - loss: 1.0866e-06 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 6/15
# 2/2 [==============================] - 55s 24s/step - loss: 1.8431e-07 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 2/2 [==============================] - 51s 21s/step - loss: 1.0532e-07 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 2/2 [==============================] - 60s 30s/step - loss: 1.9386e-08 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 2/2 [==============================] - 56s 23s/step - loss: 6.9442e-09 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 2/2 [==============================] - 54s 24s/step - loss: 5.7869e-10 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 2/2 [==============================] - 53s 23s/step - loss: 5.7869e-10 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 2/2 [==============================] - 58s 28s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 2/2 [==============================] - 58s 28s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 2/2 [==============================] - 58s 28s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# ...
# Epoch 6/15
# 3/3 [==============================] - 69s 19s/step - loss: 0.2901 - categorical_accuracy: 0.9962 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 7/15
# 3/3 [==============================] - 66s 18s/step - loss: 0.2694 - categorical_accuracy: 0.9981 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 8/15
# 3/3 [==============================] - 72s 21s/step - loss: 0.2617 - categorical_accuracy: 0.9981 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 9/15
# 3/3 [==============================] - 75s 21s/step - loss: 0.2482 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 10/15
# 3/3 [==============================] - 67s 18s/step - loss: 0.2298 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 11/15
# 3/3 [==============================] - 75s 22s/step - loss: 0.2224 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 12/15
# 3/3 [==============================] - 72s 21s/step - loss: 0.2080 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 13/15
# 3/3 [==============================] - 67s 18s/step - loss: 0.1934 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 14/15
# 3/3 [==============================] - 71s 20s/step - loss: 0.1799 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 15/15
# 3/3 [==============================] - 72s 21s/step - loss: 0.1661 - categorical_accuracy: 1.0000 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_120 (Dense)           (None, 300, 300, 5)       20
#
#  dense_121 (Dense)           (None, 300, 300, 5)       30
#
#  conv2d_89 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_89 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_90 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_90 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_91 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_91 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_30 (Flatten)        (None, 11560)             0
#
#  batch_normalization_30 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_122 (Dense)           (None, 5)                 57805
#
#  dense_123 (Dense)           (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 3/3 [==============================] - 83s 25s/step - loss: 2.9763 - categorical_accuracy: 0.1459 - val_loss: 0.0000e+00 - val_categorical_accuracy: 1.0000
# Epoch 2/15
# 3/3 [==============================] - 76s 23s/step - loss: 0.5144 - categorical_accuracy: 0.7527 - val_loss: 1944.5247 - val_categorical_accuracy: 0.0000e+00
# Epoch 3/15
# 3/3 [==============================] - 76s 23s/step - loss: 0.2833 - categorical_accuracy: 0.9964 - val_loss: 528.7602 - val_categorical_accuracy: 0.0000e+00
# Epoch 4/15
# 3/3 [==============================] - 78s 23s/step - loss: 0.2797 - categorical_accuracy: 0.9964 - val_loss: 28.3596 - val_categorical_accuracy: 0.1277
# Epoch 5/15
# 3/3 [==============================] - 73s 21s/step - loss: 0.2813 - categorical_accuracy: 0.9875 - val_loss: 0.2642 - val_categorical_accuracy: 0.9574
# Epoch 6/15
# 3/3 [==============================] - 78s 24s/step - loss: 0.2481 - categorical_accuracy: 0.9982 - val_loss: 139.0231 - val_categorical_accuracy: 0.0000e+00
# Epoch 7/15
# 3/3 [==============================] - 76s 23s/step - loss: 0.2345 - categorical_accuracy: 1.0000 - val_loss: 263.8516 - val_categorical_accuracy: 0.0000e+00
# Epoch 8/15
# 3/3 [==============================] - 75s 23s/step - loss: 0.2268 - categorical_accuracy: 1.0000 - val_loss: 433.6288 - val_categorical_accuracy: 0.0000e+00
# Epoch 9/15
# 3/3 [==============================] - 78s 23s/step - loss: 0.2033 - categorical_accuracy: 1.0000 - val_loss: 519.5002 - val_categorical_accuracy: 0.0000e+00
# Epoch 10/15
# 3/3 [==============================] - 76s 23s/step - loss: 0.1995 - categorical_accuracy: 1.0000 - val_loss: 462.9452 - val_categorical_accuracy: 0.0000e+00
# Epoch 11/15
# 3/3 [==============================] - 78s 24s/step - loss: 0.1921 - categorical_accuracy: 1.0000 - val_loss: 425.2705 - val_categorical_accuracy: 0.0000e+00
# Epoch 12/15
# 3/3 [==============================] - 76s 23s/step - loss: 0.1831 - categorical_accuracy: 1.0000 - val_loss: 403.4959 - val_categorical_accuracy: 0.0000e+00
# Epoch 13/15
# 3/3 [==============================] - 78s 23s/step - loss: 0.1726 - categorical_accuracy: 1.0000 - val_loss: 402.0677 - val_categorical_accuracy: 0.0000e+00
# Epoch 14/15
# 3/3 [==============================] - 78s 23s/step - loss: 0.1625 - categorical_accuracy: 1.0000 - val_loss: 398.9752 - val_categorical_accuracy: 0.0000e+00
# Epoch 15/15
# 3/3 [==============================] - 73s 21s/step - loss: 0.1560 - categorical_accuracy: 1.0000 - val_loss: 402.9597 - val_categorical_accuracy: 0.0000e+00
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_124 (Dense)           (None, 300, 300, 5)       20
#
#  dense_125 (Dense)           (None, 300, 300, 5)       30
#
#  conv2d_92 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_92 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_93 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_93 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_94 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_94 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_31 (Flatten)        (None, 11560)             0
#
#  batch_normalization_31 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_126 (Dense)           (None, 5)                 57805
#
#  dense_127 (Dense)           (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 3/3 [==============================] - 87s 27s/step - loss: 18.1229 - categorical_accuracy: 0.4017 - val_loss: 2.9472 - val_categorical_accuracy: 0.9850
# Epoch 2/15
# 3/3 [==============================] - 77s 23s/step - loss: 0.2984 - categorical_accuracy: 0.9467 - val_loss: 0.6411 - val_categorical_accuracy: 0.9850
# Epoch 3/15
# 3/3 [==============================] - 89s 27s/step - loss: 0.3517 - categorical_accuracy: 0.9583 - val_loss: 0.6255 - val_categorical_accuracy: 0.9850
# Epoch 4/15
# 3/3 [==============================] - 80s 25s/step - loss: 0.3012 - categorical_accuracy: 0.9583 - val_loss: 0.6160 - val_categorical_accuracy: 0.9850
# Epoch 5/15
# 3/3 [==============================] - 81s 25s/step - loss: 0.2884 - categorical_accuracy: 0.9550 - val_loss: 0.6080 - val_categorical_accuracy: 0.9850
# Epoch 6/15
# 3/3 [==============================] - 80s 24s/step - loss: 0.1864 - categorical_accuracy: 0.9583 - val_loss: 0.6016 - val_categorical_accuracy: 0.9850
# Epoch 7/15
# 3/3 [==============================] - 83s 26s/step - loss: 0.1667 - categorical_accuracy: 0.9583 - val_loss: 2.7191 - val_categorical_accuracy: 0.9200
# Epoch 8/15
# 3/3 [==============================] - 80s 24s/step - loss: 0.1668 - categorical_accuracy: 0.9583 - val_loss: 0.6146 - val_categorical_accuracy: 0.9800
# Epoch 9/15
# 3/3 [==============================] - 77s 23s/step - loss: 0.2002 - categorical_accuracy: 0.9583 - val_loss: 2.2005 - val_categorical_accuracy: 0.9450
# Epoch 10/15
# 3/3 [==============================] - 80s 25s/step - loss: 0.1566 - categorical_accuracy: 0.9583 - val_loss: 10.3680 - val_categorical_accuracy: 0.7900
# Epoch 11/15
# 3/3 [==============================] - 81s 26s/step - loss: 0.1713 - categorical_accuracy: 0.9583 - val_loss: 0.5845 - val_categorical_accuracy: 0.9850
# Epoch 12/15
# 3/3 [==============================] - 80s 25s/step - loss: 0.1321 - categorical_accuracy: 0.9583 - val_loss: 0.5818 - val_categorical_accuracy: 0.9850
# Epoch 13/15
# 3/3 [==============================] - 84s 26s/step - loss: 0.1272 - categorical_accuracy: 0.9583 - val_loss: 0.8833 - val_categorical_accuracy: 0.9750
# Epoch 14/15
# 3/3 [==============================] - 82s 25s/step - loss: 0.1200 - categorical_accuracy: 0.9583 - val_loss: 0.7432 - val_categorical_accuracy: 0.9800
# Epoch 15/15
# 3/3 [==============================] - 85s 27s/step - loss: 0.1211 - categorical_accuracy: 0.9583 - val_loss: 1.2420 - val_categorical_accuracy: 0.9650
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_128 (Dense)           (None, 300, 300, 5)       20
#
#  dense_129 (Dense)           (None, 300, 300, 5)       30
#
#  conv2d_95 (Conv2D)          (None, 297, 297, 10)      810
#
#  max_pooling2d_95 (MaxPoolin  (None, 148, 148, 10)     0
#  g2D)
#
#  conv2d_96 (Conv2D)          (None, 145, 145, 10)      1610
#
#  max_pooling2d_96 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_97 (Conv2D)          (None, 69, 69, 10)        1610
#
#  max_pooling2d_97 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_32 (Flatten)        (None, 11560)             0
#
#  batch_normalization_32 (Bat  (None, 11560)            46240
#  chNormalization)
#
#  dense_130 (Dense)           (None, 5)                 57805
#
#  dense_131 (Dense)           (None, 2)                 12
#
# =================================================================
# Total params: 108,137
# Trainable params: 85,017
# Non-trainable params: 23,120
# _________________________________________________________________
# Epoch 1/15
# 3/3 [==============================] - 87s 27s/step - loss: 3.8721 - categorical_accuracy: 0.5683 - val_loss: 11.8130 - val_categorical_accuracy: 0.9343
# Epoch 2/15
# 3/3 [==============================] - 86s 28s/step - loss: 0.3260 - categorical_accuracy: 0.8995 - val_loss: 17.9350 - val_categorical_accuracy: 0.9343
# Epoch 3/15
# 3/3 [==============================] - 85s 28s/step - loss: 0.2746 - categorical_accuracy: 0.9011 - val_loss: 12.3414 - val_categorical_accuracy: 0.9343
# Epoch 4/15
# 3/3 [==============================] - 85s 27s/step - loss: 0.2534 - categorical_accuracy: 0.8980 - val_loss: 9.1976 - val_categorical_accuracy: 0.9343
# Epoch 5/15
# 3/3 [==============================] - 89s 29s/step - loss: 0.2409 - categorical_accuracy: 0.9011 - val_loss: 26.8132 - val_categorical_accuracy: 0.9343
# Epoch 6/15
# 3/3 [==============================] - 87s 27s/step - loss: 0.2375 - categorical_accuracy: 0.9011 - val_loss: 37.4267 - val_categorical_accuracy: 0.9343
# Epoch 7/15
# 3/3 [==============================] - 85s 28s/step - loss: 0.2385 - categorical_accuracy: 0.9011 - val_loss: 37.8295 - val_categorical_accuracy: 0.9343
# Epoch 8/15
# 3/3 [==============================] - 88s 28s/step - loss: 0.2303 - categorical_accuracy: 0.9011 - val_loss: 33.0202 - val_categorical_accuracy: 0.9343
# Epoch 9/15
# 3/3 [==============================] - 85s 28s/step - loss: 0.2145 - categorical_accuracy: 0.9011 - val_loss: 26.4835 - val_categorical_accuracy: 0.9343
# Epoch 10/15
# 3/3 [==============================] - 86s 27s/step - loss: 0.2164 - categorical_accuracy: 0.9011 - val_loss: 27.8046 - val_categorical_accuracy: 0.9343
# Epoch 11/15
# 3/3 [==============================] - 87s 28s/step - loss: 0.2149 - categorical_accuracy: 0.8995 - val_loss: 30.7157 - val_categorical_accuracy: 0.9343
# Epoch 12/15
# 3/3 [==============================] - 88s 29s/step - loss: 0.2402 - categorical_accuracy: 0.8995 - val_loss: 27.7875 - val_categorical_accuracy: 0.9343
# Epoch 13/15
# 3/3 [==============================] - 85s 28s/step - loss: 0.2339 - categorical_accuracy: 0.9011 - val_loss: 23.6158 - val_categorical_accuracy: 0.9343
# Epoch 14/15
# 3/3 [==============================] - 85s 28s/step - loss: 0.2342 - categorical_accuracy: 0.9011 - val_loss: 19.8386 - val_categorical_accuracy: 0.9343
# Epoch 15/15
# 3/3 [==============================] - 86s 28s/step - loss: 0.2323 - categorical_accuracy: 0.8995 - val_loss: 13.6186 - val_categorical_accuracy: 0.9343
